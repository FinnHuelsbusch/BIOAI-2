# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import os

# %%
jsons = []
# iterate through all files in the train directory
for file in os.listdir('train'):
    if file.endswith('.json'):
        with open('train/' + file) as f:
            data = json.load(f)
            jsons.append(data)

# %%
for json in jsons:
    print(json['instance_name'])
    patients = json['patients']
    x_patient = []
    y_patient = []
    for key, value in patients.items():
        x_patient.append(value['x_coord'])
        y_patient.append(value['y_coord'])
    plt.scatter(x_patient, y_patient)
    # depot
    plt.scatter(json['depot']['x_coord'], json['depot']['y_coord'], color='red')
    plt.show()
# Out:
# train_6
# train_9
# train_4
# train_3
# train_2
# train_0
# train_5
# train_1
# train_8
# train_7

# %%
#scatter plot all the patients use the the end_time as the color
for json in jsons: 
    print(json['instance_name'])
    patients = json['patients']
    x_patient = []
    y_patient = []
    end_time = []
    for key, value in patients.items():
        x_patient.append(value['x_coord'])
        y_patient.append(value['y_coord'])
        end_time.append(int(value['end_time']))
        #use warm cold color map
    sns.scatterplot(x=x_patient, y=y_patient, hue=end_time, palette='coolwarm')
    plt.show()
# Out:
# train_6
# train_9
# train_4
# train_3
# train_2
# train_0
# train_5
# train_1
# train_8
# train_7

# %%
# check if the distance matrix is symmetric
for json in jsons:
    distance_matrix = json['travel_times']
    for i in range(len(distance_matrix)):
        for j in range(len(distance_matrix[i])):
            if distance_matrix[i][j] != distance_matrix[j][i]:
                print('Distance matrix is not symmetric for instance ' + json['instance_name'])
